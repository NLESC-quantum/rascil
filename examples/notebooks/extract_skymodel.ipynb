# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 16
plt.rcParams["figure.figsize"] = fig_size

from rascil.data_models import import_skymodel_from_hdf5

sm = import_skymodel_from_hdf5("/Users/timcornwell/Code/rascil/test_results/test-imaging-pipeline-dask_continuum_imaging_skymodel.hdf")

# %%
from rascil.processing_components import show_skymodel

show_skymodel([sm[0]], vmax=0.01)
